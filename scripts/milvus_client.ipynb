# %%
from pymilvus import MilvusClient, DataType

# 1. Set up a Milvus client
client = MilvusClient(
    uri="http://localhost:19530"
)
# Out:
# Failed to create new connection using: 3b01b87287c648bf9e09ea1e9203a584
# ---------------------------------------------------------------------------
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 4
#       3 # 1. Set up a Milvus client
# ----> 4 client = MilvusClient(
#       5     uri="http://localhost:19530"
#       6 )
#
# File ~/.local/lib/python3.10/site-packages/pymilvus/milvus_client/milvus_client.py:58, in MilvusClient.__init__(self, uri, user, password, db_name, token, timeout, **kwargs)
#      46 """A client for the common Milvus use case.
#      47
#      48 This client attempts to hide away the complexity of using Pymilvus. In a lot ofcases what
#    (...)
#      56         to None.
#      57 """
# ---> 58 self._using = self._create_connection(
#      59     uri, user, password, db_name, token, timeout=timeout, **kwargs
#      60 )
# ...
